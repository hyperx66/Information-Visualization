# %% [markdown]
# # Install & Import Libraries

# %%
# !pip3 install Flask

import csv, flask
# Out:
# Requirement already satisfied: Flask in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: Jinja2>=3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Flask) (3.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Flask) (2.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Flask) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Flask) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Jinja2>=3.0->Flask) (2.0.1)
# WARNING: You are using pip version 22.0.4; however, version 22.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.

# %% [markdown]
# # Data Processing

# %% [markdown]
# Prepare CSV file for reading

# %%
file = open('owid-covid-data.csv')
csvreader = csv.reader(file)

# %% [markdown]
# Retrieve all countries from Europe category

# %%
rows = []
countries = []
numRow = 0

for row in csvreader:
    if numRow>0:
        rows.append(row)
    else:
        numRow = numRow + 1

for row in rows:
    if(row[1].strip().lower() == "europe"):
        if(row[2] not in countries):
            countries.append(row[2])

print(countries)
# Out:
# ['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Faeroe Islands', 'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Guernsey', 'Hungary', 'Iceland', 'Ireland', 'Isle of Man', 'Italy', 'Jersey', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom', 'Vatican']

# %% [markdown]
# Go through the csv again to get data sort according to the year and month and respective details

# %%
countryDict = {}

for country in countries:
    countryDict[country] = {}
    for row in rows:
        dateData = row[3]
        dateSplit = dateData.split("/")
        month = int(dateSplit[0])
        year = int(dateSplit[2])
        try:
            yearData = countryDict[country][year]
        except:
            templateData = {"Q1":{"stringencyTotal":0, "stringencyReadings":0, "covidCases":0, "death":0, "stringencyAvg":0},"Q2":{"stringencyTotal":0, "stringencyReadings":0, "covidCases":0, "death":0, "stringencyAvg":0},"Q3":{"stringencyTotal":0, "stringencyReadings":0, "covidCases":0, "death":0, "stringencyAvg":0},"Q4":{"stringencyTotal":0, "stringencyReadings":0, "covidCases":0, "death":0, "stringencyAvg":0}}
            countryDict[country][year] = templateData
        
        stringencyIndex = 0.00
        covidCaseNum = 0
        deaths = 0
        try:
            deaths = int(row[7])
        except:
            deaths = 0
        try:
            covidCaseNum = int(row[5])
        except:
            covidCaseNum = 0
        try:
            stringencyIndex = float(row[47])
        except:
            stringencyIndex = 0.00

        if month <= 3:
            currentTotal = countryDict[country][year]["Q1"]["stringencyTotal"]
            currentReading = countryDict[country][year]["Q1"]["stringencyReadings"]
            countryDict[country][year]["Q1"]["stringencyTotal"] = currentTotal + stringencyIndex
            countryDict[country][year]["Q1"]["stringencyReadings"] = currentReading + 1

            currentCovidCase = countryDict[country][year]["Q1"]["covidCases"]
            countryDict[country][year]["Q1"]["covidCases"] = currentCovidCase + covidCaseNum
            currentDeath = countryDict[country][year]["Q1"]["death"]
            countryDict[country][year]["Q1"]["death"] = currentDeath + deaths

        elif month>3 and month<=6:
            currentTotal = countryDict[country][year]["Q2"]["stringencyTotal"]
            currentReading = countryDict[country][year]["Q2"]["stringencyReadings"]
            countryDict[country][year]["Q2"]["stringencyTotal"] = currentTotal + stringencyIndex
            countryDict[country][year]["Q2"]["stringencyReadings"] = currentReading + 1

            currentCovidCase = countryDict[country][year]["Q2"]["covidCases"]
            countryDict[country][year]["Q2"]["covidCases"] = currentCovidCase + covidCaseNum
            currentDeath = countryDict[country][year]["Q2"]["death"]
            countryDict[country][year]["Q2"]["death"] = currentDeath + deaths
        
        elif month>6 and month<=9:
            currentTotal = countryDict[country][year]["Q3"]["stringencyTotal"]
            currentReading = countryDict[country][year]["Q3"]["stringencyReadings"]
            countryDict[country][year]["Q3"]["stringencyTotal"] = currentTotal + stringencyIndex
            countryDict[country][year]["Q3"]["stringencyReadings"] = currentReading + 1

            currentCovidCase = countryDict[country][year]["Q3"]["covidCases"]
            countryDict[country][year]["Q3"]["covidCases"] = currentCovidCase + covidCaseNum
            currentDeath = countryDict[country][year]["Q3"]["death"]
            countryDict[country][year]["Q3"]["death"] = currentDeath + deaths
        
        else:
            currentTotal = countryDict[country][year]["Q4"]["stringencyTotal"]
            currentReading = countryDict[country][year]["Q4"]["stringencyReadings"]
            countryDict[country][year]["Q4"]["stringencyTotal"] = currentTotal + stringencyIndex
            countryDict[country][year]["Q4"]["stringencyReadings"] = currentReading + 1

            currentCovidCase = countryDict[country][year]["Q4"]["covidCases"]
            countryDict[country][year]["Q4"]["covidCases"] = currentCovidCase + covidCaseNum
            currentDeath = countryDict[country][year]["Q4"]["death"]
            countryDict[country][year]["Q4"]["death"] = currentDeath + deaths
print(countryDict)
# Out:
# {'Albania': {2020: {'Q1': {'stringencyTotal': 233407.66999999806, 'stringencyReadings': 6859, 'covidCases': 3862175, 'death': 2003602, 'stringencyAvg': 0}, 'Q2': {'stringencyTotal': 1184947.6999999862, 'stringencyReadings': 20126, 'covidCases': 39586478, 'death': 123364214, 'stringencyAvg': 0}, 'Q3': {'stringencyTotal': 958383.0999999963, 'stringencyReadings': 20540, 'covidCases': 95905443, 'death': 308600484, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 903741.0299999728, 'stringencyReadings': 20859, 'covidCases': 208475982, 'death': 542899592, 'stringencyAvg': 0}}, 2021: {'Q1': {'stringencyTotal': 934911.189999959, 'stringencyReadings': 20784, 'covidCases': 194223455, 'death': 923598133, 'stringencyAvg': 0}, 'Q2': {'stringencyTotal': 925445.3999999953, 'stringencyReadings': 21600, 'covidCases': 221263599, 'death': 1327380209, 'stringencyAvg': 0}, 'Q3': {'stringencyTotal': 860148.0999999807, 'stringencyReadings': 22281, 'covidCases': 211406238, 'death': 1678088582, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 808868.200000009, 'stringencyReadings': 22122, 'covidCases': 235359656, 'death': 1960071530, 'stringencyAvg': 0}}, 2022: {'Q1': {'stringencyTotal': 753451.939999992, 'stringencyReadings': 21467, 'covidCases': 866357824, 'death': 2183042301, 'stringencyAvg': 0}, 'Q2': {'stringencyTotal': 426975.20999999513, 'stringencyReadings': 19206, 'covidCases': 227992859, 'death': 2139929269, 'stringencyAvg': 0}, 'Q3': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}}}, 'Andorra': {2020: {'Q1': {'stringencyTotal': 233407.66999999806, 'stringencyReadings': 6859, 'covidCases': 3862175, 'death': 2003602, 'stringencyAvg': 0}, 'Q2': {'stringencyTotal': 1184947.6999999862, 'stringencyReadings': 20126, 'covidCases': 39586478, 'death': 123364214, 'stringencyAvg': 0}, 'Q3': {'stringencyTotal': 958383.0999999963, 'stringencyReadings': 20540, 'covidCases': 95905443, 'death': 308600484, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 903741.0299999728, 'stringencyReadings': 20859, 'covidCases': 208475982, 'death': 542899592, 'stringencyAvg': 0}}, 2021: {'Q1': {'stringencyTotal': 934911.189999959, 'stringencyReadings': 20784, 'covidCases': 194223455, 'death': 923598133, 'stringencyAvg': 0}, 'Q2': {'stringencyTotal': 925445.3999999953, 'stringencyReadings': 21600, 'covidCases': 221263599, 'death': 1327380209, 'stringencyAvg': 0}, 'Q3': {'stringencyTotal': 860148.0999999807, 'stringencyReadings': 22281, 'covidCases': 211406238, 'death': 1678088582, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 808868.200000009, 'stringencyReadings': 22122, 'covidCases': 235359656, 'death': 1960071530, 'stringencyAvg': 0}}, 2022: {'Q1': {'stringencyTotal': 753451.939999992, 'stringencyReadings': 21467, 'covidCases': 866357824, 'death': 2183042301, 'stringencyAvg': 0}, 'Q2': {'stringencyTotal': 426975.20999999513, 'stringencyReadings': 19206, 'covidCases': 227992859, 'death': 2139929269, 'stringencyAvg': 0}, 'Q3': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}}}, 'Austria': {2020: {'Q1': {'stringencyTotal': 233407.66999999806, 'stringencyReadings': 6859, 'covidCases': 3862175, 'death': 2003602, 'stringencyAvg': 0}, 'Q2': {'stringencyTotal': 1184947.6999999862, 'stringencyReadings': 20126, 'covidCases': 39586478, 'death': 123364214, 'stringencyAvg': 0}, 'Q3': {'stringencyTotal': 958383.0999999963, 'stringencyReadings': 20540, 'covidCases': 95905443, 'death': 308600484, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 903741.0299999728, 'stringencyReadings': 20859, 'covidCases': 208475982, 'death': 542899592, 'stringencyAvg': 0}}, 2021: {'Q1': {'stringencyTotal': 934911.189999959, 'stringencyReadings': 20784, 'covidCases': 194223455, 'death': 923598133, 'stringencyAv ...

# %% [markdown]
# Calculate average stringency

# %%
allCountries = countryDict.keys()
for country in allCountries:
    yearColl = countryDict[country].keys()
    for year in yearColl:
        quarterColl = countryDict[country][year].keys()
        for quarter in quarterColl:
            try:
                countryDict[country][year][quarter]["stringencyAvg"] = round(countryDict[country][year][quarter]["stringencyTotal"]/countryDict[country][year][quarter]["stringencyReadings"], 2)
            except:
                countryDict[country][year][quarter]["stringencyAvg"] = 0
print(countryDict)
# Out:
# {'Albania': {2020: {'Q1': {'stringencyTotal': 233407.66999999806, 'stringencyReadings': 6859, 'covidCases': 3862175, 'death': 2003602, 'stringencyAvg': 34.03}, 'Q2': {'stringencyTotal': 1184947.6999999862, 'stringencyReadings': 20126, 'covidCases': 39586478, 'death': 123364214, 'stringencyAvg': 58.88}, 'Q3': {'stringencyTotal': 958383.0999999963, 'stringencyReadings': 20540, 'covidCases': 95905443, 'death': 308600484, 'stringencyAvg': 46.66}, 'Q4': {'stringencyTotal': 903741.0299999728, 'stringencyReadings': 20859, 'covidCases': 208475982, 'death': 542899592, 'stringencyAvg': 43.33}}, 2021: {'Q1': {'stringencyTotal': 934911.189999959, 'stringencyReadings': 20784, 'covidCases': 194223455, 'death': 923598133, 'stringencyAvg': 44.98}, 'Q2': {'stringencyTotal': 925445.3999999953, 'stringencyReadings': 21600, 'covidCases': 221263599, 'death': 1327380209, 'stringencyAvg': 42.84}, 'Q3': {'stringencyTotal': 860148.0999999807, 'stringencyReadings': 22281, 'covidCases': 211406238, 'death': 1678088582, 'stringencyAvg': 38.6}, 'Q4': {'stringencyTotal': 808868.200000009, 'stringencyReadings': 22122, 'covidCases': 235359656, 'death': 1960071530, 'stringencyAvg': 36.56}}, 2022: {'Q1': {'stringencyTotal': 753451.939999992, 'stringencyReadings': 21467, 'covidCases': 866357824, 'death': 2183042301, 'stringencyAvg': 35.1}, 'Q2': {'stringencyTotal': 426975.20999999513, 'stringencyReadings': 19206, 'covidCases': 227992859, 'death': 2139929269, 'stringencyAvg': 22.23}, 'Q3': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}}}, 'Andorra': {2020: {'Q1': {'stringencyTotal': 233407.66999999806, 'stringencyReadings': 6859, 'covidCases': 3862175, 'death': 2003602, 'stringencyAvg': 34.03}, 'Q2': {'stringencyTotal': 1184947.6999999862, 'stringencyReadings': 20126, 'covidCases': 39586478, 'death': 123364214, 'stringencyAvg': 58.88}, 'Q3': {'stringencyTotal': 958383.0999999963, 'stringencyReadings': 20540, 'covidCases': 95905443, 'death': 308600484, 'stringencyAvg': 46.66}, 'Q4': {'stringencyTotal': 903741.0299999728, 'stringencyReadings': 20859, 'covidCases': 208475982, 'death': 542899592, 'stringencyAvg': 43.33}}, 2021: {'Q1': {'stringencyTotal': 934911.189999959, 'stringencyReadings': 20784, 'covidCases': 194223455, 'death': 923598133, 'stringencyAvg': 44.98}, 'Q2': {'stringencyTotal': 925445.3999999953, 'stringencyReadings': 21600, 'covidCases': 221263599, 'death': 1327380209, 'stringencyAvg': 42.84}, 'Q3': {'stringencyTotal': 860148.0999999807, 'stringencyReadings': 22281, 'covidCases': 211406238, 'death': 1678088582, 'stringencyAvg': 38.6}, 'Q4': {'stringencyTotal': 808868.200000009, 'stringencyReadings': 22122, 'covidCases': 235359656, 'death': 1960071530, 'stringencyAvg': 36.56}}, 2022: {'Q1': {'stringencyTotal': 753451.939999992, 'stringencyReadings': 21467, 'covidCases': 866357824, 'death': 2183042301, 'stringencyAvg': 35.1}, 'Q2': {'stringencyTotal': 426975.20999999513, 'stringencyReadings': 19206, 'covidCases': 227992859, 'death': 2139929269, 'stringencyAvg': 22.23}, 'Q3': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}, 'Q4': {'stringencyTotal': 0, 'stringencyReadings': 0, 'covidCases': 0, 'death': 0, 'stringencyAvg': 0}}}, 'Austria': {2020: {'Q1': {'stringencyTotal': 233407.66999999806, 'stringencyReadings': 6859, 'covidCases': 3862175, 'death': 2003602, 'stringencyAvg': 34.03}, 'Q2': {'stringencyTotal': 1184947.6999999862, 'stringencyReadings': 20126, 'covidCases': 39586478, 'death': 123364214, 'stringencyAvg': 58.88}, 'Q3': {'stringencyTotal': 958383.0999999963, 'stringencyReadings': 20540, 'covidCases': 95905443, 'death': 308600484, 'stringencyAvg': 46.66}, 'Q4': {'stringencyTotal': 903741.0299999728, 'stringencyReadings': 20859, 'covidCases': 208475982, 'death': 542899592, 'stringencyAvg': 43.33}}, 2021: {'Q1': {'stringencyTotal': 934911.189999 ...

# %% [markdown]
# # Prepare API

# %% [markdown]
# API will receive a GET request and return the dictionary as a JSON

# %%
app = flask.Flask(__name__)

@app.route('/', methods=['GET'])
def displayData():
    response = flask.jsonify(countryDict)
    response.headers.add('Access-Control-Allow-Origin', '*')
    return response

app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [27/Jul/2022 01:49:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:49:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:49:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:49:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:49:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:50:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:51:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:52:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:53:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:54:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:55:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:56:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:56:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:56:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:58:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:58:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:58:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:58:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:59:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:59:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 01:59:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:05:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:05:51] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:06:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:06:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:10:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:10:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:10:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:11:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:11:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:11:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:11:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:12:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:12:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:12:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:12:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:12:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:12:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:13:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:13:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:13:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:13:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:13:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:13:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:13:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:14:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:14:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:14:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:14:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:14:51] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:14:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:14:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:15:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:16:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:17:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:18:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:18:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 02:18:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 03:18:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 03:23:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 03:23:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:20:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:20:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:20:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:21:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:22:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:25:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:26:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:26:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:26:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:27:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:27:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:27:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:27:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:27:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:29:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:29:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:29:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:29:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:30:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:30:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:30:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:30:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:30:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:30:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:51] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:31:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:32:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:33:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:34:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:34:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:34:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:34:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:35:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:37:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:37:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:37:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:37:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:38:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:38:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:38:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:38:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:38:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:38:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:38:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:39:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:39:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:39:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:39:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:39:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:40:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:40:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:40:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:40:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:40:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:41:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:41:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:42:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:43:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:44:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:44:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:44:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:44:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:44:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:45:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:48:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:49:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:49:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:49:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:49:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:49:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:50:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:52:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:53:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:54:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:54:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:54:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:54:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:55:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:55:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:55:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:56:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:57:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:57:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:57:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:57:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:57:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:57:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:59:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:59:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:59:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 04:59:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:02:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:03:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:03:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:03:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:03:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:04:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:04:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:04:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:04:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:04:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:04:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:04:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:05:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:05:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:05:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:05:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:05:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:05:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:06:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:06:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:06:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:07:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:07:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:08:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:08:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:08:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:08:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:09:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:09:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:09:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:09:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:10:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:10:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:10:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:10:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:10:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:10:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:12:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:13:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:20:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:20:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:20:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:21:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:21:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:21:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:21:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:22:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:23:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:23:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:23:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:23:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:23:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:24:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:24:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:24:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Jul/2022 05:24:19] "GET / HTTP/1.1" 200 -
